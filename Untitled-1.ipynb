# %%
from reporteine import ReporteINE
from time import time
from datosipc import datosIPC
from funcionesjo import mes_by_ordinal

# %%
t = time()
mes = 2
anio = 2023
mes_ = mes_by_ordinal(mes, abreviado=False).capitalize()
fecha = f"{mes_} {anio}"
datos = datosIPC(anio, mes, QdbAux=True, dbBackup=True)
reporte = ReporteINE("Índice de Precios al Consumidor", anio, mes)
# Out:
# R[write to console]: WARNING: Rtools is required to build R packages, but is not currently installed.
#
# Please download and install Rtools 4.2 from https://cran.r-project.org/bin/windows/Rtools/ or https://www.r-project.org/nosvn/winutf8/ucrt3/.
#
# R[write to console]: Skipping install of 'funcionesINE' from a github remote, the SHA1 (9a81f89d) has not changed since last install.
#   Use `force = TRUE` to force installation
#
# R[write to console]: Exiting.

# %%
# capitulo 1
reporte.presentacion(datos.introduccion())
reporte.agregar_capitulo(
    titulo="Detalle del operativo de campo del IPC"
)
subcap_data = datos.serie_fuentes()
reporte.agregar_subcapitulo(
    titulo="Cobertura de fuentes",
    titulo_grafico="Histórico de cobertura de fuentes",
    descripcion_grafico="República de Guatemala, serie histórica, cantidad de fuentes",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True)
)
subcap_data = datos.serie_precios()
reporte.agregar_subcapitulo(
    titulo="Cobertura de precios",
    titulo_grafico="Histórico de cobertura de precios",
    descripcion_grafico="República de Guatemala, serie histórica, cantidad de precios",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True)
)
subcap_data = datos.serie_imputacion()
reporte.agregar_subcapitulo(
    titulo="Imputación de precios",
    titulo_grafico="Histórico de imputación de precios",
    descripcion_grafico="República de Guatemala, serie histórica, porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="columna",
    data=subcap_data[0],
    opciones_grafico={}
)
subcap_data = datos.desagregacion_fuentes()
reporte.agregar_subcapitulo(
    titulo="Desagregación de fuentes",
    titulo_grafico="Desagregación de fuentes por tipo",
    descripcion_grafico=f"República de Guatemala, {fecha}, porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
# capitulo 2
reporte.agregar_capitulo(
    titulo="Variables exógenas"
)
subcap_data = datos.indice_precio_alimentos()
reporte.agregar_subcapitulo(
    titulo="Precio internacional de los alimentos",
    titulo_grafico="Índice de precios de los alimentos de la FAO",
    descripcion_grafico="Indicador internacional, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="FAO",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.petroleo()
reporte.agregar_subcapitulo(
    titulo="Precio del pretróleo",
    titulo_grafico="Precio promedio mensual del barril del petróleo",
    descripcion_grafico="Indicador internacional, serie histórica, en dólares por barril",
    descripcion=subcap_data[1],
    fuente="Federal Reserve Economic Data",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.cambio_quetzal()
reporte.agregar_subcapitulo(
    titulo="Cambio del quetzal",
    titulo_grafico="Tipo de cambio nominal promedio",
    descripcion_grafico="República de Guatemala, serie histórica, en quetzales por dólar estadounidense",
    descripcion=subcap_data[1],
    fuente="Banco de Guatemala",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.tasa_interes()
reporte.agregar_subcapitulo(
    titulo="Tasa de interés",
    titulo_grafico="Tasas de interés activa bancaria",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="Banco de Guatemala",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.ipc_usa()
reporte.agregar_subcapitulo(
    titulo="Índice de Precios al Consumidor de EE.UU.",
    titulo_grafico="Variación interanual del IPC de Estados Unidos de América",
    descripcion_grafico="Estados Unidos de América, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="FRED",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)

subcap_data = datos.ipc_mex()
reporte.agregar_subcapitulo(
    titulo="Índice de Precios al Consumidor de México",
    titulo_grafico="Variación interanual del IPC de México",
    descripcion_grafico="Estados Unidos Mexicanos, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="FRED",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
"""
subcap_data = datos.inflacion_CA_RD_MEX()
reporte.agregar_subcapitulo(
    titulo="Inflación en Centro América, República Dominicana y México",
    titulo_grafico="Tasa de variación interanual del IPC de los países Centroamericanos, República Dominicana y México",
    descripcion_grafico="Centro América, República Dominicana y México, meses seleccionados, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="tabla",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
"""
# capitulo 3
reporte.agregar_capitulo(
    titulo="Resultados del IPC"
)
subcap_data = datos.serie_IPC(0)
reporte.agregar_subcapitulo(
    titulo="Evolución del IPC",
    titulo_grafico="IPC, base diciembre del 2010",
    descripcion_grafico="República de Guatemala, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.serie_inflacion(0, 'interanual')
reporte.agregar_subcapitulo(
    titulo="Evolución del cambio anual del IPC (Ritmo Inflacionario)",
    titulo_grafico="Variación interanual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.serie_inflacion(0, 'acumulada')
reporte.agregar_subcapitulo(
    titulo="Evolución de la variación acumulada del IPC",
    titulo_grafico="Variación acumulada del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="columna",
    data=subcap_data[0],
    opciones_grafico={}
)
subcap_data = datos.serie_inflacion(0, 'intermensual')
reporte.agregar_subcapitulo(
    titulo="Evolución de la variación mensual del IPC",
    titulo_grafico="Variación intermensual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.incidencias_divisiones(0)
reporte.agregar_subcapitulo(
    titulo="Incidencias mensuales por división de gasto básico",
    titulo_grafico="Incidencias mensuales",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.incidencias_gba(0, True)
reporte.agregar_subcapitulo(
    titulo="Gastos básicos con mayor impacto positivo en la variación mensual",
    titulo_grafico="Gastos básicos con mayor incidencia positiva",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.incidencias_gba(0, False)
reporte.agregar_subcapitulo(
    titulo="Gastos básicos con mayor impacto negativo en la variación mensual",
    titulo_grafico="Gastos básicos con mayor incidencia negativa",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.serie_poder_adquisitivo(0)
reporte.agregar_subcapitulo(
    titulo="Valor del Quetzal",
    titulo_grafico="Poder adquisitivo del quetzal",
    descripcion_grafico="República de Guatemala, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
# capitulos regionales
region = {
    1: 'I',
    2: 'II',
    3: 'III',
    4: 'IV',
    5: 'V',
    6: 'VI',
    7: 'VII',
    8: 'VIII'
}
for RegCod in range(1, 9):
    reporte.agregar_capitulo(
        titulo=f"Resultados para la región {region[RegCod]}"
    )
    subcap_data = datos.serie_IPC(RegCod)
    reporte.agregar_subcapitulo(
        titulo=f"Evolución del índice en la región {region[RegCod]}",
        titulo_grafico="Índice de la región, base diciembre del 2010",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, adimensional",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'interanual', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación interanual del índice en la región {region[RegCod]}",
        titulo_grafico="Variación interanual del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'acumulada', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación acumulada del índice en la región {region[RegCod]}",
        titulo_grafico="Variación acumulada del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="columna",
        data=subcap_data[0],
        opciones_grafico={}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'intermensual', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación mensual del índice en la región {region[RegCod]}",
        titulo_grafico="Variación intermensual del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    subcap_data = datos.incidencias_divisiones(RegCod)
    reporte.agregar_subcapitulo(
        titulo="Incidencias mensuales por división de gasto básico",
        titulo_grafico="Incidencias mensuales",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    subcap_data = datos.incidencias_gba(RegCod, True)
    reporte.agregar_subcapitulo(
        titulo="Gastos básicos con mayor impacto positivo en la variación mensual",
        titulo_grafico="Gastos básicos con mayor incidencia positiva",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    subcap_data = datos.incidencias_gba(RegCod, False)
    reporte.agregar_subcapitulo(
        titulo="Gastos básicos con mayor impacto negativo en la variación mensual",
        titulo_grafico="Gastos básicos con mayor incidencia negativa",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    """
    subcap_data = datos.serie_poder_adquisitivo(RegCod)
    reporte.agregar_subcapitulo(
        titulo="Valor del Quetzal",
        titulo_grafico="Poder adquisitivo del quetzal",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, adimensional",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    """

# %%
reporte.crear_reporte()
# Out:
# R[write to console]: Creating new TikZ metrics dictionary at:
# 	C:/Users/laalvarado/tikzMetricsDictionary
#
# R[write to console]: Using TikZ metrics dictionary at:
# 	C:/Users/laalvarado/tikzMetricsDictionary
#
# R[write to console]: Measuring dimensions of: \char77
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c7b5e67f1" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char103
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c5e8648b6" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char106
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c718e257d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char112
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c5cd33bec" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char113
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c7add1709" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char121
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c3451c6d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char81
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c59de1412" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: gjpqyQ
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8cc2874f" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: -2500
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c1752790a" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 0
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c23554825" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2500
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c3f756b5" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 5000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c16a72381" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 7500
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8cca030d4" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Feb-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6aaf2ab7" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Mar-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c148a1001" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Abr-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c27a97ce3" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: May-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c49ee6ada" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Jun-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c72ae192d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Jul-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c28d32a61" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Ago-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c472b264b" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Sep-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c20264da3" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Oct-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c64915348" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Nov-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8cd0c7098" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Dic-2022
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c444e3584" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Ene-2023
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c773a4b" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Feb-2023
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2bfd47fd" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 6,009
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2f8763a" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: \char77
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2fd96fcc" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 7,165
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c4ad45d00" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 0
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c397829f3" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: -10000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c18595031" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 10000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c66b64655" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 20000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2c72d86" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 30000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c54ef5406" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 40000
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8cd7a1d3a" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 31,473
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2c7122c5" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 38,208
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8ce4e7fb3" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of:
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c307dc7" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2.67
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c4ba65e65" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2.78
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c55bc3b7" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.08
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c13a543f4" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.37
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c69713ffa" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.49
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6bae1f98" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 4.39
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2ed6937" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.03
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c287a17c6" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 4.44
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6dc86917" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 5.29
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c4c67700d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.29
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6a7f1149" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 4.28
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c201363e" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.24
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2bb021ca" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2.07
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c392a2acf" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 0.00
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c338d463" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Almacenes
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c637c5881" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Apartamento de Alquiler
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c258b6173" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Carnicerias
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2053f41" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Casa de Alquiler
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c605a71ee" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Centros Educativos
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c3003564c" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Centros de Salud
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c741a32a6" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Cuarto de Alquiler
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c59c22997" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Depositos
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c48cc5cc9" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Empresas
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c65ba566e" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Expendios de Gas
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c90647ab" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Farmacias
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c7d5db5b" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Hipermercados
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c24eb17c6" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Hoteles
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c65f91f49" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Mercados
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c15b5f00" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Otros Establecimientos Especializados
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c498c53e9" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Otros Establecimientos No Especializados
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2767122c" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Restaurantes
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c1d91755" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Servicio Domestico
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c80877d2" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Sin tipo
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c19bb8f4" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Supermercados
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c28107433" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: Tiendas no Especializadas
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c78ba459d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 120
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c48605688" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 130
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6cdc3eff" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 140
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c5e5cb8b" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 150
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6bd2240" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 160
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c709c5938" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 141.24
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c7be211e4" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 159.71
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c2be47d5" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 129.79
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c34b36f1" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 70
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c44571c30" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 80
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c60476d50" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 90
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c76e7728" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 100
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8cf8df77" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 110
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c3f106e6e" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Feb
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c4a872545" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Mar
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c14c6728d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Abr
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c54f17a2d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-May
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c46ac1628" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Jun
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c48a35e97" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Jul
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c44862a83" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Ago
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c53ab1883" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Sep
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c6df16546" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Oct
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c1c9f4770" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Nov
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c395237d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2022-Dic
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c41323f7c" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2023-Ene
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c470c1de2" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2023-Feb
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c23041fcc" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 91.64
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c34f6125f" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 114.84
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c76bf282e" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 76.44
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c460c26cf" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 76.83
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpQhemor\tikzDevice1c8c495f11fd" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 7