# %%
from datosipc import datosIPC

from funcionesjo import mes_by_ordinal
from reporteine import ReporteINE

# %%
mes = 4
anio = 2023
mes_ = mes_by_ordinal(mes, abreviado=False).capitalize()
fecha = f"{mes_} {anio}"
datos = datosIPC(anio, mes, dbBackup=1)
reporte = ReporteINE("Índice de Precios al Consumidor", anio, mes)

# %%
subcap_data_imputacion = list(datos.serie_imputacion())
eliminar = subcap_data_imputacion[0][-1]
subcap_data_imputacion[0].remove(eliminar)
subcap_data_imputacion[0].append(('Abr-2023', 1.60))
subcap_data_imputacion[1] = 'El porcentaje de precios imputados en abril 2023 es de 1.60%. El mayor porcentaje de imputaciones fue en el mes de octubre 2022 con una cantidad de 5.28% y el menor se encuentra en el mes de abril 2023 con una cantidad de 1.60%.'

# %%
# capitulo 1
reporte.presentacion(datos.introduccion())
reporte.agregar_capitulo(
    titulo="Detalle del operativo de campo del IPC"
)
subcap_data = datos.serie_fuentes()
reporte.agregar_subcapitulo(
    titulo="Cobertura de fuentes",
    titulo_grafico="Histórico de cobertura de fuentes",
    descripcion_grafico="República de Guatemala, serie histórica, cantidad de fuentes",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True)
)
subcap_data = datos.serie_precios()
reporte.agregar_subcapitulo(
    titulo="Cobertura de precios",
    titulo_grafico="Histórico de cobertura de precios",
    descripcion_grafico="República de Guatemala, serie histórica, cantidad de precios",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True)
)
subcap_data = subcap_data_imputacion
reporte.agregar_subcapitulo(
    titulo="Imputación de precios",
    titulo_grafico="Histórico de imputación de precios",
    descripcion_grafico="República de Guatemala, serie histórica, porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="columna",
    data=subcap_data[0],
    opciones_grafico={"precision":1}
)
subcap_data = datos.desagregacion_fuentes()
reporte.agregar_subcapitulo(
    titulo="Desagregación de fuentes",
    titulo_grafico="Desagregación de fuentes por tipo",
    descripcion_grafico=f"República de Guatemala, {fecha}, porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":1}
)
# capitulo 2
reporte.agregar_capitulo(
    titulo="Variables exógenas"
)
subcap_data = datos.indice_precio_alimentos()
reporte.agregar_subcapitulo(
    titulo="Precio internacional de los alimentos",
    titulo_grafico="Índice de precios de los alimentos de la FAO",
    descripcion_grafico="Indicador internacional, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="FAO",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.petroleo()
reporte.agregar_subcapitulo(
    titulo="Precio del pretróleo",
    titulo_grafico="Precio promedio mensual del barril del petróleo",
    descripcion_grafico="Indicador internacional, serie histórica, en dólares por barril",
    descripcion=subcap_data[1],
    fuente="Federal Reserve Economic Data",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.cambio_quetzal()
reporte.agregar_subcapitulo(
    titulo="Cambio del quetzal",
    titulo_grafico="Tipo de cambio nominal promedio",
    descripcion_grafico="República de Guatemala, serie histórica, en quetzales por dólar estadounidense",
    descripcion=subcap_data[1],
    fuente="Banco de Guatemala",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.tasa_interes()
reporte.agregar_subcapitulo(
    titulo="Tasa de interés",
    titulo_grafico="Tasas de interés activa bancaria",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="Banco de Guatemala",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.ipc_usa()
reporte.agregar_subcapitulo(
    titulo="Índice de Precios al Consumidor de EE.UU.",
    titulo_grafico="Variación interanual del IPC de Estados Unidos de América",
    descripcion_grafico="Estados Unidos de América, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="FRED",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)

subcap_data = datos.ipc_mex()
reporte.agregar_subcapitulo(
    titulo="Índice de Precios al Consumidor de México",
    titulo_grafico="Variación interanual del IPC de México",
    descripcion_grafico="Estados Unidos Mexicanos, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="FRED",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
'''
subcap_data = datos.inflacion_CA_RD_MEX()
reporte.agregar_subcapitulo(
    titulo="Inflación en Centro América, República Dominicana y México",
    titulo_grafico="Tasa de variación interanual del IPC de los países Centroamericanos, República Dominicana y México",
    descripcion_grafico="Centro América, República Dominicana y México, meses seleccionados, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="tabla",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
'''

# capitulo 3
reporte.agregar_capitulo(
    titulo="Resultados del IPC"
)
subcap_data = datos.serie_IPC(0)
reporte.agregar_subcapitulo(
    titulo="Evolución del IPC",
    titulo_grafico="IPC, base diciembre del 2010",
    descripcion_grafico="República de Guatemala, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.serie_inflacion(0, 'interanual')
reporte.agregar_subcapitulo(
    titulo="Evolución del cambio anual del IPC (Ritmo Inflacionario)",
    titulo_grafico="Variación interanual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.serie_inflacion(0, 'acumulada')
reporte.agregar_subcapitulo(
    titulo="Evolución de la variación acumulada del IPC",
    titulo_grafico="Variación acumulada del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="columna",
    data=subcap_data[0],
    opciones_grafico={}
)
subcap_data = datos.serie_inflacion(0, 'intermensual')
reporte.agregar_subcapitulo(
    titulo="Evolución de la variación mensual del IPC",
    titulo_grafico="Variación intermensual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":1, "Q4Etiquetas":True}
)
subcap_data = datos.incidencias_divisiones(0)
reporte.agregar_subcapitulo(
    titulo="Incidencias mensuales por división de gasto básico",
    titulo_grafico="Incidencias mensuales",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.incidencias_gba(0, True)
reporte.agregar_subcapitulo(
    titulo="Gastos básicos con mayor impacto positivo en la variación mensual",
    titulo_grafico="Gastos básicos con mayor incidencia positiva",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.incidencias_gba(0, False)
reporte.agregar_subcapitulo(
    titulo="Gastos básicos con mayor impacto negativo en la variación mensual",
    titulo_grafico="Gastos básicos con mayor incidencia negativa",
    descripcion_grafico=f"República de Guatemala, {fecha}, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="barra",
    data=subcap_data[0],
    opciones_grafico={"precision":2}
)
subcap_data = datos.serie_poder_adquisitivo(0)
reporte.agregar_subcapitulo(
    titulo="Valor del Quetzal",
    titulo_grafico="Poder adquisitivo del quetzal",
    descripcion_grafico="República de Guatemala, serie histórica, adimensional",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico={"precision":2, "Q4Etiquetas":True}
)
subcap_data = datos.serie_historica("mensual")
reporte.agregar_subcapitulo(
    titulo="Serie histórica del la variación mensual",
    titulo_grafico="Variación intermensual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True, etiquetaCadaSeis=True)
)
subcap_data = datos.serie_historica("anual")
reporte.agregar_subcapitulo(
    titulo="Serie histórica del ritmo inflacionario",
    titulo_grafico="Variación interanual del IPC",
    descripcion_grafico="República de Guatemala, serie histórica, en porcentaje",
    descripcion=subcap_data[1],
    fuente="INE",
    tipo_grafico="lineal",
    data=subcap_data[0],
    opciones_grafico=dict(Q4Etiquetas=True, etiquetaCadaSeis=True)
)
# capitulos regionales
region = {
    1: 'I',
    2: 'II',
    3: 'III',
    4: 'IV',
    5: 'V',
    6: 'VI',
    7: 'VII',
    8: 'VIII'
}
for RegCod in range(1, 9):
    reporte.agregar_capitulo(
        titulo=f"Resultados para la región {region[RegCod]}"
    )
    subcap_data = datos.serie_IPC(RegCod)
    reporte.agregar_subcapitulo(
        titulo=f"Evolución del índice en la región {region[RegCod]}",
        titulo_grafico="Índice de la región, base diciembre del 2010",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, adimensional",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":1, "Q4Etiquetas":True}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'interanual', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación interanual del índice en la región {region[RegCod]}",
        titulo_grafico="Variación interanual del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'acumulada', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación acumulada del índice en la región {region[RegCod]}",
        titulo_grafico="Variación acumulada del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="columna",
        data=subcap_data[0],
        opciones_grafico={}
    )
    subcap_data = datos.serie_inflacion(RegCod, 'intermensual', nivel=f'en la región {region[RegCod]}')
    reporte.agregar_subcapitulo(
        titulo=f"Evolución de la variación mensual del índice en la región {region[RegCod]}",
        titulo_grafico="Variación intermensual del índice",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":1, "Q4Etiquetas":True}
    )
    subcap_data = datos.incidencias_divisiones(RegCod)
    reporte.agregar_subcapitulo(
        titulo="Incidencias mensuales por división de gasto básico",
        titulo_grafico="Incidencias mensuales",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    subcap_data = datos.incidencias_gba(RegCod, True)
    reporte.agregar_subcapitulo(
        titulo="Gastos básicos con mayor impacto positivo en la variación mensual",
        titulo_grafico="Gastos básicos con mayor incidencia positiva",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    subcap_data = datos.incidencias_gba(RegCod, False)
    reporte.agregar_subcapitulo(
        titulo="Gastos básicos con mayor impacto negativo en la variación mensual",
        titulo_grafico="Gastos básicos con mayor incidencia negativa",
        descripcion_grafico=f"Region {region[RegCod]}, {fecha}, en porcentaje",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="barra",
        data=subcap_data[0],
        opciones_grafico={"precision":2}
    )
    """
    subcap_data = datos.serie_poder_adquisitivo(RegCod)
    reporte.agregar_subcapitulo(
        titulo="Valor del Quetzal",
        titulo_grafico="Poder adquisitivo del quetzal",
        descripcion_grafico=f"Region {region[RegCod]}, serie histórica, adimensional",
        descripcion=subcap_data[1],
        fuente="INE",
        tipo_grafico="lineal",
        data=subcap_data[0],
        opciones_grafico={"precision":2, "Q4Etiquetas":True}
    )
    """
#capitulo 4
reporte.agregar_capitulo(
    titulo="Anexos",
    anexo=True
)
datos_gba = datos.series_Gba(0)
for Gba in datos_gba:
    nombre = Gba[0]
    datosGba = Gba[1]
    desc = Gba[2]
    reporte.agregar_subcapitulo(
        titulo=f"Evolución del índice del gasto básico {nombre}",
        titulo_grafico="IPC, base diciembre del 2010",
        descripcion_grafico="República de Guatemala, serie histórica, adimensional",
        descripcion=desc,
        fuente="INE",
        tipo_grafico="lineal",
        data=datosGba,
        opciones_grafico={"precision":1, "Q4Etiquetas":True}
    )

# %%
reporte.crear_reporte()
reporte.compilar_reporte()
reporte.compilar_reporte()
# Out:
# R[write to console]: Using TikZ metrics dictionary at:
# 	/Users/jo/Dictionary/tikzMetricsDictionary
#
# R[write to console]: Measuring dimensions of: 6,683
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572b16e59f' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 8,680
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572c3d2f69' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 33,671
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724f39cc6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 46,252
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257215b98db4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2023-Abr
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257249062f90' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 101.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572351cbc64' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 73.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257271946479' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 79.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257245507e30' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 8.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572278ca4dd' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 5.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257229bbd74' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 6.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723eb30c02' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 7.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725cd97776' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 7.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257249321399' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 170.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257276a4c759' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.62
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c1be0e9' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 8.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724a4affd3' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.30
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721e19bc0' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.97
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722b85b37' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.88
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572156c7946' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.50
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257248deda7' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721ed7147' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.05
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572ba7ed4e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.55
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723dcca1dc' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.43
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257245969236' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.58
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257220593aeb' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572422b2ae4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572200d00ac' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.16
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257235a72ca4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.10
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727263de80' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.16
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727aa4e02b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Servicios De Viajes Todo Incluido Dentro Del País
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725e7965f4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.09
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727414a6a0' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.05
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257277c78de9' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 8.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724e35f96e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 5.00
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572398accdf' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 5.86
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572479061fc' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.60
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257258110c18' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.77
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572473128d3' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.12
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726c6f5928' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.86
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257224688b6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.52
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257264b965e4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.80
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257247d08f65' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.02
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724d7654b8' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257213b423c3' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.28
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721797e150' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.24
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257274495749' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.28
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727b01b543' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.23
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722d2380cc' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Gasolina Regular
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257275dce83a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.15
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727a127449' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Servicio De Fiestas
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725190a33b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Carne De Res
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726ecca052' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.15
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c31a052' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 229.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725e14865d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 257.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572158173ec' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.50
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257265e195fb' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 12.40
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723d3dc5fe' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.38
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722291c61b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.37
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257210652858' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.26
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572613bb1d0' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.82
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721617008f' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.43
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724025b79d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.87
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726c39c551' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -1.60
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257244c98059' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.46
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125729097657' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.93
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724c384e63' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.7
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724a26cad' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.71
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572438cd43b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.71
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257252c19022' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.16
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257221ddd2a0' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.37
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726a2f17be' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 149.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257239bff168' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 160.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257268820076' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 6.45
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722eec7894' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 7.27
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257226e0549d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.14
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257251d3235b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.93
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727cb65554' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.31
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572269c3dc3' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.18
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725b9ae102' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.91
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572152a794a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.73
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721780f421' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572131bae95' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.09
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727e62c1ff' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.13
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725ae8d2c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 217.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726b6469e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 237.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257228d63283' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 8.98
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257268e4b67' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.16
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257267f85a8d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.24
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726201144e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.73
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257234dc3f26' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.27
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257267b5f2e6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.01
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725a5e0f3b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.48
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572553a18d6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.22
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725934b550' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572136bc4f1' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.46
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257284eb42d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.46
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726716fa9d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.05
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572159f8e4b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.33
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721e36e904' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.80
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257226fc151b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Repollo
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726fcdb39b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Chile Pimiento
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257229cabe75' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 156
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723d9e08c2' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.34
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257252511828' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 7.85
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724a091450' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.06
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721a14b629' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.87
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257245c34b1f' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.83
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257218790401' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -1.00
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257230f5ea34' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.54
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257260e31508' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.62
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725c79f1e9' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.37
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257249f9276d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.81
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257248b8b0c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 2.02
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726555c328' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572617fab11' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.04
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724b81b19' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Otras Comidas Consumidas  Fuera Del Hogar
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257252fb08ba' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.21
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725efa15e5' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.21
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257274b39e19' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 210.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c50b72a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 234.7
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257257294555' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.72
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725686fc27' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 11.72
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572381490d2' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.39
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724e2fe7c1' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.90
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722b185801' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 3.38
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724b39bfc1' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.46
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c5c3e7c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.49
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724c0a5dd9' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.22
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c97788f' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.14
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727c6c135c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of:  0.14
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721b6b3cd5' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721d66d203' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.11
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724965d209' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723bc07284' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.45
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572579e56c1' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: Zanahoria
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725c51c5d7' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.45
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727c93d59a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 160.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724dacb15b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 172.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724aff534' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 4.13
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723c0b2b53' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 7.54
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257214974f1' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.32
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727d9c7adf' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.64
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722c4706e6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -1.72
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726b15fcbf' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: -0.31
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257270849685' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 1.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257210b62f79' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 0.11
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257228e6b981' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 159.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572439cd921' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 217.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726e732834' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 280
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724a54a692' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 283.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727b83e15d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 349.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572f40e005' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 131.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726c337015' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 141.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722503aa32' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 191.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572139acb9a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 195.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257217acf584' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 134.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725c2ab940' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 144.7
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257278e84805' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 157.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257259d07e46' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 239.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257271253bb' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 261.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257244371d9d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 173.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727e795167' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 132.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724ecf820f' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 143.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721963cf35' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 221.4
#
# ...
#
# R[write to console]: Measuring dimensions of: 106.20
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257232b28ab' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 106.24
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257267af42d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 106.28
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727234b9ad' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 104.88
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572638a476e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 104.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572b57b9d0' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.00
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722c680c81' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.25
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572630cffed' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.50
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726a765368' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.75
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727e5e0772' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 86.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724f3b0e2e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 87.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722e2016a5' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 98.00
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723caec24b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 99.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727555e90c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 98.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725b374f02' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 94.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572c243b17' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721ea3693b' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727a51b033' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 95.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125729072302' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 92.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572338b5cef' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 84.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722826959' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 86.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723fd25358' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 86.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257295dd724' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 84.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125726fd78149' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 113.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722d6918fc' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 108.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724ee75fae' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 109.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572383ac0fa' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 109.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572195379ed' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 110.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723769c398' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 112.7
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572a84c94' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 153.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572293b88e2' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 105.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572397c294' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 165.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257260678463' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 167.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722c24b107' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 161.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721ce25935' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 161.2
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572504eb563' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 166.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725f669fc5' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 203.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724a836f71' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 178.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125727b0989ee' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 198.7
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722f3ea75d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 113.4
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125723a5de2e6' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 113.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257269db87f9' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 144.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724bbc22ba' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 142.3
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722c8c082e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 165.8
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721d6d1adb' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 179.9
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257265fe2ef4' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 148.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257212bcc97c' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 143
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572284ff580' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 143.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice12572197ebb2d' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 189
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125724f32946e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 181.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125721aeea61' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 188.6
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257229d8724' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 118.1
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice1257234134dd3' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 106.0
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725f5a725a' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 140.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125722b09a39e' 'tikzStringWidthCalc.tex'
#
# R[write to console]: Measuring dimensions of: 96.5
#
# R[write to console]: Running command: '/Library/TeX/texbin/xelatex' -interaction=batchmode -halt-on-error -output-directory '/var/folders/ql/hb1_ww5s1ms1rqldb7pmg2f80000gn/T//Rtmp92BO7D/tikzDevice125725d4f025' 'tikzStringWidthCalc.tex'
