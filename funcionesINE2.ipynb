# %%
import os
os.environ["R_HOME"] = r"C:\Users\laalvarado\AppData\Local\Programs\R\R-4.2.2" # change as needed
import rpy2.robjects.packages as rpackages
import rpy2.robjects as robjects
import pandas as pd
from rpy2.robjects import pandas2ri

pandas2ri.activate()

# %%
class FuncionesINE:
    def __init__(self) -> None:
        # devtools = rpackages.importr('devtools')
        # devtools.install_github("1u1s4/funcionesINE")
        self.__funcionesINE = rpackages.importr('funcionesINE')
        self.__datos = list
        self.Qanual = True

    def cargaMasiva(self, csv_path: str) -> None:
        self.__datos = self.__funcionesINE.cargaMasiva(csv_path, codificacion='UTF8')

    def escribirCSV(self, ruta_libro: str, ruta_salida: str) -> None:
        self.__funcionesINE.escribirCSV(
            lista=self.__funcionesINE.leerLibro(ruta=ruta_libro),
            ruta=ruta_salida
            )

    def escribirCSVcocinado(self, ruta_libro: str, ruta_salida: str) -> None:
        self.__funcionesINE.escribirCSV(
            lista=self.__funcionesINE.leerLibroNormal(ruta=ruta_libro),
            ruta=ruta_salida
            )

    def graficaLinea(
        self,
        data: pd.DataFrame,
        ruta_salida: str,
        nombre: str,
        inicio: int = -1,
        ancho: float = 1.5,
        precision: int = 1,
        escala: str = "normal",
        rotar: bool = True,
        final = None,
        etiquetaCadaSeis: bool = False,
        Q4Etiquetas: bool = False) -> None:
        r_data = pandas2ri.py2rpy(data)  # Convierte el DataFrame de pandas a un objeto R

        if self.Qanual:
            self.__funcionesINE.anual(
                robjects.r("rgb(0,0,1)"),
                robjects.r("rgb(0.6156862745098039,0.7333333333333333,1)")
            )
        if Q4Etiquetas:
            self.__funcionesINE.cuatroEtiquetas()
        rotar = robjects.r("TRUE") if rotar else robjects.r("FALSE")
        etiquetaCadaSeis = robjects.r("TRUE") if etiquetaCadaSeis else robjects.r("FALSE")
        if final is None:
            final = robjects.r("NA")
        self.__funcionesINE.exportarLatex(
            ruta_salida + f"/{nombre}.tex",
            self.__funcionesINE.graficaLinea(
                r_data,
                inicio=inicio,
                ancho=ancho,
                precision=precision,
                escala=escala,
                rotar=rotar,
                final=final,
                etiquetaCadaSeis=etiquetaCadaSeis
            ),
            preambulo = robjects.r("TRUE")
        )

    def graficaBar(
        self,
        data_index: int,
        ruta_salida: str,
        nombre: str,
        precision: int = 2,
        ancho: float = 0.6,
        ordenar: bool = True,
        escala = 'normal') -> None:
        if self.Qanual:
            self.__funcionesINE.anual(
                robjects.r("rgb(0,0,1)"),
                robjects.r("rgb(0.6156862745098039,0.7333333333333333,1)")
            )
        if ordenar:
            ordenar = robjects.r("TRUE")
        else:
            ordenar = robjects.r("FALSE")
        g = self.__funcionesINE.graficaBar(
                    self.__datos.rx(data_index)[0],
                    ancho=ancho,
                    ordenar=ordenar,
                    escala=escala
                )
        g =  self.__funcionesINE.etiquetasBarras(
                g,
                precision=precision
            )
        self.__funcionesINE.exportarLatex(
            ruta_salida + f"/{nombre}.tex",
            g
        )

    def graficaCol(
        self,
        data_index: int,
        ruta_salida: str,
        nombre: str,
        precision: int = 2,
        ancho: float = 0.6,
        ordenar: bool = False,
        escala = 'normal') -> None:
        if self.Qanual:
            self.__funcionesINE.anual(
                robjects.r("rgb(0,0,1)"),
                robjects.r("rgb(0.6156862745098039,0.7333333333333333,1)")
            )
        if ordenar:
            ordenar = robjects.r("TRUE")
        else:
            ordenar = robjects.r("FALSE")
        g = self.__funcionesINE.graficaCol(
                    self.__datos.rx(data_index)[0],
                    ancho=ancho,
                    ordenar=ordenar,
                    escala=escala
                )
        g =  self.__funcionesINE.etiquetasHorizontales(
                g,
                precision=precision
            )
        g = self.__funcionesINE.rotarEtiX(g)
        self.__funcionesINE.exportarLatex(
            ruta_salida + f"/{nombre}.tex",
            g
        )

# %%
p = FuncionesINE()

# %%
import numpy as np
X = np.linspace(0, 10, 10)
Y = np.linspace(0, 10, 10)
p.graficaLinea(data=pd.DataFrame({'x':X, 'y':Y}), ruta_salida='Temp', nombre='prueba')
# Out:
# R[write to console]: Using TikZ metrics dictionary at:
# 	C:/Users/laalvarado/tikzMetricsDictionary
#
# R[write to console]: Measuring dimensions of: 2.22222222222222
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8104da85d42" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.33333333333333
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8105ff63ff7" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 4.44444444444444
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8107a3b16e6" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 5.55555555555556
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8103edf10fe" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 6.66666666666667
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8102d09172" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 7.77777777777778
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice81072c7883" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 8.88888888888889
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice81031553794" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 0.0
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8104cb532c9" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 1.1
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice81068f924c8" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 2.2
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice810aef3d54" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 3.3
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8103f0979cf" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 5.6
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice810bd2efa" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 6.7
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8102db3455e" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 7.8
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8106b70663d" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 8.9
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice8105b69513" "tikzStringWidthCalc.tex"
#
# R[write to console]: Measuring dimensions of: 10.0
#
# R[write to console]: Running command: "C:\texlive\2022\bin\win32\xelatex.exe" -interaction=batchmode -halt-on-error -output-directory "C:\Users\LAALVA~1\AppData\Local\Temp\RtmpCWJLnR\tikzDevice81018a351d8" "tikzStringWidthCalc.tex"
